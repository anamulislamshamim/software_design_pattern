# %% [markdown]
# **L — Liskov Substitution Principle (LSP)**
#
# Definition: "If class B (Child) is a subclass of class A (Parent), then you should be able to replace A (Parent) with B (Child) without breaking the program."
#
# In simple words: <br>
# - Child class must honor the contract of the parent class
# - No surprises
# - No broken behavior
#
# Why **LSP** matters in backend systems? <br>
#
# Backend systems rely heavily on: <br>
# - Interfaces
# - Abstractions
# - Dependency injection
#
# Breaking **LSP** leads to: <br>
# - Runtime bugs
# - Weird edge cases
# - Broken APIs

# %% [markdown]
# **Classic LSP Violation (Easy Example)**
#
# Wrong Design

# %%
class Bird:
    def fly(self):
        print("Flying")

class Penguin(Bird):
    def fly(self):
        raise Exception("Penguins can't fly")

# %% [markdown]
# Why this breaks LSP?

# %%
def make_bird_fly(bird: Bird):
    bird.fly()

make_bird_fly(Penguin()) # 💥 crash
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 def make_bird_fly(bird: Bird):
#       2     bird.fly()
# ----> 4 make_bird_fly(Penguin()) # 💥 crash
#
# Cell In[4], line 2, in make_bird_fly(bird)
#       1 def make_bird_fly(bird: Bird):
# ----> 2     bird.fly()
#
# Cell In[2], line 7, in Penguin.fly(self)
#       6 def fly(self):
# ----> 7     raise Exception("Penguins can't fly")
#
# Exception: Penguins can't fly

# %% [markdown]
# You can not substitute (replace) Bird with Penguin.
#
# 👉 Inheritance lie detected

# %% [markdown]
# **Correct Design**

# %%
class Bird:
    pass 

class FlyingBird(Bird):
    def fly(self):
        print("Flying")

class Penguin(Bird):
    def swim(self):
        print("Swimming")

# %% [markdown]
# ✔ Now substitution is safe

# %% [markdown]
# **Backend-Oriented Example 1: File Storage Service**
#
# Very common in backend systems.

# %% [markdown]
# **Bad Design (LSP Violation)**

# %%
# Interface
class FileStorage:
    def save(self, file):
        raise NotImplementedError

    def get_public_url(self, file):
        raise NotImplementedError

# %% [markdown]
# **S3 Implementation**

# %%
class S3Storage(FileStorage):
    def save(self, file):
        print("File saved to s3")
    
    def get_public_url(self, file):
        return f"https://s3.amazonaws.com/file/{file}"

# %% [markdown]
# **Local Storage**

# %%
class LocalStorage(FileStorage):
    def save(self, file):
        print("File saved locally")
    
    def get_public_url(self, file):
        # since local storage has no public url so raise Exception
        raise Exception("Local storage has no public URL")

# %% [markdown]
# **Usage**

# %%
s3 = S3Storage()
s3.save("shamim.txt")
s3.get_public_url("shamim.txt")
# Out:
# File saved to s3
# 'https://s3.amazonaws.com/file/shamim.txt'

# %%
local = LocalStorage()
local.save("shamim.txt")
local.get_public_url("shamim.txt")
# Out:
# File saved locally
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 local = LocalStorage()
#       2 local.save("shamim.txt")
# ----> 3 local.get_public_url("shamim.txt")
#
# Cell In[8], line 7, in LocalStorage.get_public_url(self, file)
#       5 def get_public_url(self, file):
#       6     # since local storage has no public url so raise Exception
# ----> 7     raise Exception("Local storage has no public URL")
#
# Exception: Local storage has no public URL

# %% [markdown]
# **Correct Design (Split responsibilities - SRP + LSP)**

# %%
class Storage:
    def save(self, file):
        raise NotImplementedError

class PublicStorage(Storage):
    def get_public_url(self, file):
        raise NotImplementedError

# %% [markdown]
# Implementations

# %%
class S3Storage(PublicStorage):
    def save(self, file):
        print(f"{file} saved to S3")
    
    def get_public_url(self, file):
        return f"https://s3.amazon.com/file/{file}"

class LocalStorage(Storage):
    def save(self, file):
        print(f"{file} saved to local storage successfully!")

# %% [markdown]
# **Usage**

# %%
s3 = S3Storage()
s3.save("shamim.txt")
s3.get_public_url("shamim.txt")
# Out:
# shamim.txt saved to S3
# 'https://s3.amazon.com/file/shamim.txt'

# %%
local = LocalStorage()
local.save("shamim.txt")
# Out:
# shamim.txt saved to local storage successfully!

# %% [markdown]
# ✔ LSP preserved <br>
# ✔ No fake behavior
